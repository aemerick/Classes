# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pyCloudy as pc

# %%
# adding some imports
import os

import a.stromgren as parta

starsDict = parta.defineStars()

# %%
dir_ = './'

# Adding some inputs ---- Andrew E.

# Directory to output figures:
fig_dir = dir_ + "control"
if not os.path.isdir(fig_dir): os.mkdir(fig_dir)

# desired line widths
linewidth = 1.25
fsize = 6.0

# %%
# Define verbosity to high level (will print errors, warnings and messages)
pc.log_.level = 3

# %%
# The directory in which we will have the model
# You may want to change this to a different place so that the current directory
# will not receive all the Cloudy files.
dir_ = './model/'
if not os.path.isdir(dir_): os.mkdir(dir_)

# %%
# Define some parameters of the model:
model_name = 'midterm_v1'
full_model_name = '{0}{1}'.format(dir_, model_name)
# Density of cloud (uniform density)
dens = 3. #log cm-3
# Effective blackbody temperature of Central Star
Teff = 37130. #K
# Rate of production of Hydrogen ionizing photons
qH = 49.23 #s-1
# Inner radius
r_min = 5e16 #cm
# Outer radius (if needed)
#r_max = 2e18 #cm
dist = 1.26 #kpc

# %%
# these are the commands common to all the models (here only one ...)
options = ('no molecules',
            'no level2 lines',
            'no fine opacities',
            'atom h-like levels small',
            'atom he-like levels small',
            'COSMIC RAY BACKGROUND',
            'element limit off -8',
            'print line optical depth', 
            'metals 1.0 linear'
            )

# %%
emis_tab = ['H  1  4861',
            'H  1  6563',
            'He 1  5876',
            'O  1  6300',
            'O II  3726',
            'O II  3729',
            'S II  6731',
            'S II  6716',
            'O  3  5007', 
            'O  3  4959',
            'O  3  4931',
            'N  2  6584',
            'N  2  6548',
            'N  2  5755',
            'TOTL  4363',
            'TOTL  4861',
            'O  1 63.17m',
            'O  1 145.5m',
            'C  2 157.6m']

print len(emis_tab)
# Out:
# 19

# %%
abund = {'He' : -0.92, 'C' : 6.85 - 12, 'N' : -4.0, 'O' : -3.40, 'Ne' : -4.00, 
         'S' : -5.35, 'Ar' : -5.80, 'Fe' : -7.4, 'Cl' : -7.00}

# %%
# Defining the object that will manage the input file for Cloudy
c_input = pc.CloudyInput(full_model_name)

# %%
# Filling the object with the parameters
# Defining the ionizing SED: Effective temperature and luminosity.
# The lumi_unit is one of the Cloudy options, like "luminosity solar", "q(H)", "ionization parameter", etc... 
c_input.set_BB(Teff = Teff, lumi_unit = 'q(H)', lumi_value = qH)

# %%
# Defining the density. You may also use set_dlaw(parameters) if you have a density law defined in dense_fabden.cpp.
c_input.set_cste_density(dens)

# %%
# Defining the inner radius. A second parameter would be the outer radius (matter-bounded nebula).
#c_input.set_radius(r_in=np.log10(r_min),r_out=np.log10(r_max))
c_input.set_radius(r_in=np.log10(r_min))
c_input.set_abund(ab_dict = abund, nograins = True)
c_input.set_other(options)
c_input.set_iterate() # (0) for no iteration, () for one iteration, (N) for N iterations.
c_input.set_sphere() # () or (True) : sphere, or (False): open geometry.
c_input.set_emis_tab(emis_tab) # better use read_emis_file(file) for long list of lines, where file is an external file.
c_input.set_distance(dist=dist, unit='kpc', linear=True) # unit can be 'kpc', 'Mpc', 'parsecs', 'cm'. If linear=False, the distance is in log.

# %%
# Writing the Cloudy inputs. to_file for writing to a file (named by full_model_name). verbose to print on the screen.
c_input.print_input(to_file = True, verbose = False)
# Out:
#      CloudyInput: Input writen in ./model/midterm_v1.in

# %%
# Printing some message to the screen
pc.log_.message('Running {0}'.format(model_name), calling = 'test1')
# Out:
#      test1: Running midterm_v1

# %%
# Running Cloudy with a timer. Here we reset it to 0.
pc.log_.timer('Starting Cloudy', quiet = True, calling = 'test1')
c_input.run_cloudy()
pc.log_.timer('Cloudy ended after seconds:', calling = 'test1')
# Out:
#      run_cloudy: running: cd ./model ;  /home/emerick/code/c13.03/source/cloudy.exe
#      run_cloudy: ending: cd ./model ;  /home/emerick/code/c13.03/source/cloudy.exe
#    test1: Cloudy ended after seconds: in 41.8963038921

# %%
# Reading the Cloudy outputs in the Mod CloudyModel object
Mod = pc.CloudyModel(full_model_name)
# Out:
#      CloudyModel: Creating CloudyModel for ./model/midterm_v1
#      CloudyModel: Li abundance not defined
#      CloudyModel: B abundance not defined
#      CloudyModel: Sc abundance not defined
#      CloudyModel: ./model/midterm_v1.rad read
#      CloudyModel: Number of zones: 232
#      CloudyModel: ./model/midterm_v1.phy read
#      CloudyModel: ./model/midterm_v1.ele_H read
#      CloudyModel: filling H with 3 columns
#      CloudyModel: ./model/midterm_v1.ele_He read
#      CloudyModel: filling He with 3 columns
#      CloudyModel: ./model/midterm_v1.ele_C read
#      CloudyModel: filling C with 13 columns
#      CloudyModel: ./model/midterm_v1.ele_N read
#      CloudyModel: filling N with 8 columns
#      CloudyModel: ./model/midterm_v1.ele_O read
#      CloudyModel: filling O with 12 columns
#      CloudyModel: ./model/midterm_v1.ele_Ne read
#      CloudyModel: filling Ne with 11 columns
#      CloudyModel: ./model/midterm_v1.ele_Ar read
#      CloudyModel: filling Ar with 19 columns
#      CloudyModel: ./model/midterm_v1.ele_S read
#      CloudyModel: filling S with 17 columns
#      CloudyModel: ./model/midterm_v1.ele_Cl read
#      CloudyModel: filling Cl with 18 columns
#      CloudyModel: ./model/midterm_v1.ele_Fe read
#      CloudyModel: filling Fe with 27 columns
#      CloudyModel: ./model/midterm_v1.ele_Si read
#      CloudyModel: filling Si with 15 columns
#      CloudyModel: ./model/midterm_v1.emis read
#      CloudyModel: Number of emissivities: 19
#      CloudyModel: ./model/midterm_v1.cont read

# %%
plt.figure(figsize=(fsize,fsize))
plt.plot(Mod.radius, Mod.get_ionic('H', 1), label = 'HII',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_ionic('H', 0), label = 'HI',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_ionic('He', 0), label = 'HeI',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_ionic('He', 1), label = 'HeII',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_ionic('He', 2), label = 'HeIII',linewidth=linewidth)
plt.xlabel('Radius',fontsize=18)
plt.ylabel(r'$x_{ion}$',fontsize=18)
plt.title('Ionization Zones')
plt.legend(loc=3)
plt.savefig(fig_dir + "/IonizationZones.png")

# %%
plt.figure(figsize=(fsize,fsize))
plt.plot(Mod.radius, Mod.te, label = 'Te',linewidth=linewidth)
plt.xlabel('Radius',fontsize=18)
plt.ylabel(r'Electron Temperature ($T_e$)',fontsize=18)
plt.legend(loc=3)
plt.savefig(fig_dir + "/ElectronTemperature.png")

# %%
# printing line intensities
for line in Mod.emis_labels:
    print('{0} {1:10.3e} {2:7.2f}'.format(line, Mod.get_emis_vol(line), Mod.get_emis_vol(line) / Mod.get_emis_vol('H__1__4861A') * 100.))
# Out:
# H__1__4861A  8.005e+36  100.00
# H__1__6563A  2.367e+37  295.65
# HE_1__5876A  1.065e+36   13.30
# O__1__6300A  5.343e+34    0.67
# O_II__3726A  8.602e+36  107.46
# O_II__3729A  7.038e+36   87.93
# S_II__6731A  2.817e+35    3.52
# S_II__6716A  2.220e+35    2.77
# O__3__5007A  1.407e+37  175.74
# O__3__4959A  4.674e+36   58.39
# O__3__4931A  1.912e+33    0.02
# N__2__6584A  1.109e+37  138.50
# N__2__6548A  3.757e+36   46.93
# N__2__5755A  1.011e+35    1.26
# TOTL__4363A  3.150e+34    0.39
# TOTL__4861A  8.005e+36  100.00
# O__1_6317M  1.757e+34    0.22
# O__1_1455M  1.431e+33    0.02
# C__2_1576M  2.580e+33    0.03

# %%
plt.figure(figsize=(fsize,fsize))
plt.plot(Mod.radius, Mod.get_emis('H__1__6563A'), label = r'H$\alpha$',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_emis('H__1__4861A'), label = r'H$\beta$',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_emis('O__3__5007A'), label = '[OIII]',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_emis('N__2__6584A'), label = '[NII]',linewidth=linewidth)
plt.plot(Mod.radius, Mod.get_emis('S_II__6716A'), label = '[SII]',linewidth=linewidth)
plt.xlabel('Radius',fontsize=18)
plt.ylabel(r'Emissivity',fontsize=18)

plt.legend()
plt.savefig(fig_dir + "/Emissivity.png")

# %%
plt.figure(figsize=(fsize,fsize))
plt.scatter(np.log10(Mod.ne),Mod.te,  c = Mod.depth/np.max(Mod.depth), edgecolors = 'none')
plt.colorbar(label='Normalized depth')
plt.xlabel(r'log N$_e$ [cm$^{-3}$]',fontsize=18)
plt.ylabel('T$_e$ [K]',fontsize=18)
plt.savefig(fig_dir + "/T_vs_N-depth.png")

# %%
plt.figure(figsize=(fsize,fsize))
plt.scatter(np.log10(Mod.ne),( Mod.get_emis('S_II__6716A')/Mod.get_emis('S_II__6731A')), c = Mod.radius/np.max(Mod.radius), edgecolors = 'none',label=r'$\frac{SII6716\AA}{SII6731\AA}$')
plt.colorbar(label='Normalized radius')
plt.xlabel(r'log n$_e$',fontsize=18)
plt.ylabel('Ratio',fontsize=18)
plt.title('Density Diagnostic',fontsize=18)
plt.legend(fontsize=18)
plt.savefig(fig_dir + "/DensityDiagnostic.png")

# %%
plt.figure(figsize=(fsize,fsize))
plt.scatter(np.log10( Mod.get_emis('N__2__6584A')/Mod.get_emis('H__1__4861A')),np.log10(Mod.get_emis('O__3__5007A')/Mod.get_emis('H__1__6563A')), c = Mod.radius/np.max(Mod.radius), edgecolors = 'none',label='Full region')
plt.xlim((-1.8, 0.8))
plt.ylim((-1.2, 1.2))
plt.colorbar(label='Normalized radius')
plt.title(r'BPT Diagram',fontsize=18)
plt.xlabel('log NII/Halpha',fontsize=18)
plt.ylabel('log OIII/Hbeta',fontsize=18)
plt.legend(fontsize=18)
plt.savefig(fig_dir + "/BPTDiagram.png")

# %%
plt.figure(figsize=(fsize,fsize))
plt.loglog(Mod.get_cont_x(unit='Ang'), Mod.get_cont_y(cont = 'incid', unit = 'Jy'), label = 'Incident',linewidth=linewidth)
plt.loglog(Mod.get_cont_x(unit='Ang'), Mod.get_cont_y(cont = 'diffout', unit = 'Jy'), label = 'Diff Out',linewidth=linewidth)
plt.loglog(Mod.get_cont_x(unit='Ang'), Mod.get_cont_y(cont = 'ntrans', unit = 'Jy'), label = 'Net Trans',linewidth=linewidth)
plt.xlim((100, 10000))
plt.ylim((1e-3, 1e5))
plt.xlabel('Angstrom')
plt.ylabel('Jy')
plt.legend(loc=4)
plt.savefig(fig_dir + "/J_spectra.png")
