# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def t(n):
    return n - np.sin(n)
def a(n):
    return 1.0 - np.cos(n)
def adot(n):
    return np.sin(n) * (1.0/(1.0 - np.cos(n)))
def rho(n,k=1):
    
    return 3.0/(8.0*np.pi)  * (adot(eta)**2 + k)/(a(eta)**2)

# %%
# for the closed universe (part a)

eta = np.linspace(0.0,1.0,1000)

# %%
plt.figure(figsize=(5,5))
plt.plot(eta,t(eta))

# %%
plt.plot(eta,a(eta))

# %%
plt.plot(eta,adot(eta))

# %%
rho = 3.0/(8.0*np.pi)  * (adot(eta)**2 + k)/(a(eta)**2)


plt.plot(np.linspace(-1.0,1.0,1000),rho)
plt.semilogy()
# Out:
# []

# %%
eta = np.linspace(-1.0,11.0,1000.0)
plt.plot(t(eta),a(eta))
plt.xlabel('t');plt.ylabel('a')

# %%
plt.plot(t(eta),rho(eta))
plt.semilogy()
plt.xlabel('t');plt.ylabel(r'$\rho$')

# %%
plt.plot(t(eta),adot(eta))
plt.xlim(0.0,6.0)
plt.ylim(1.0E-3,1.0)
plt.semilogy()
# Out:
# []
